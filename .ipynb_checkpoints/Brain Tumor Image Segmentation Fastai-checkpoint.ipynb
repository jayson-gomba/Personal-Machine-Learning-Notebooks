# %%
from fastai.vision.all import *

from fastai.data.all import *
from fastai.imports import *
from fastai.vision.core import *
import torchvision.models as models

import warnings
warnings.filterwarnings('ignore')

# %%
path_imgs = Path('Brain Tumor Images')

# %%
def label_func(fn): return path_imgs/"Masks"/f"{fn.stem}_mask{fn.suffix}"

# %%
codes = ['0', '1']

# %%
img_seg_dl = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items = get_image_files,
                   get_y = label_func,
                   splitter=RandomSplitter(), 
                   item_tfms=[ToTensor],
                   batch_tfms=[IntToFloatTensor(div_mask=255.0), *aug_transforms()])

# %%
dls = img_seg_dl.dataloaders(path_imgs/'Images', path=path_imgs, num_workers=0, bs=4)

# %%
dls.show_batch(max_n=6)

# %%
learn = unet_learner(dls, resnet18, metrics=Dice())
learn.fine_tune(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035156</td>
#       <td>0.026380</td>
#       <td>0.428204</td>
#       <td>02:17</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='747' class='' max='780' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       95.77% [747/780 01:53<00:05 0.0096]
#     </div>
